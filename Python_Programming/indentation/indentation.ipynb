# %% [markdown]
# ### Indentation:- Indentation means code can be write a right well structured without any error
# Examples are :-

# %%
print("Hello")
    x = 5   # error: unexpected indent
# Out:
#   Cell In[1], line 2
#     x = 5   # error: unexpected indent
#     ^
# IndentationError: unexpected indent

# %%
if 10 > 5:
print("10 bada hai")   
print("Yeh hamesha chalega")
# Out:
#   Cell In[1], line 2
#     print("10 bada hai")   # ye line indent hai, isliye if block ke andar hai
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
# correct indentation
if 10 > 5:
    print("10 bada hai")  
print("Yeh hamesha chalega")
# Out:
# 10 bada hai
# Yeh hamesha chalega

# %% [markdown]
# Explicit Line Continuation (Backslash \)

# %%
a=1
b=2
c=3
if (a == 1 and b == 2 and
    c == 3):
    pass
# ya backslash
if a == 1 and b == 2 \
          and c == 3:
    pass

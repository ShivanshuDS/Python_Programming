# %% [markdown]
# ### Comments:- comment is a line or block of text that python interpreter can be ignored.

# %% [markdown]
# ##### Type of comments:-
# i)-Single line comments:-#<br>
# ii):-Multiple single line comments:-#<br>
# iii):-Triple quoted string comments:- it is usefull for single and multiline comment when using once.(''' ''')(""" """)

# %% [markdown]
# i>Single Line Comments:-#

# %%
# Write a program of print sum of two numbers
x=21
y=43
x+y
# Out:
# 64

# %% [markdown]
# ii>Multi single line comments:-#

# %%
# Write a program of print sum of two numbers
# take a input from user value of x and y
# after input than perform sum
x=int(input())
y=int(input())
x+y # sum of x and y
# Out:
# 90

# %% [markdown]
# iii>Triple quoted string comments:-''' ''', """ """

# %%
'''
Hello, I am shivashu making a program my marksheet by using my sum details are:- 
Name:-Shivanshu
Course:-B.tech
Branch:-C.S.E
Subject:- Python, Java, Machine Learning, DBMS, DSA
Collage Name:- Laxmi Devi Institute Of Engineering and Technology
University Name:-Bikaner Technical University
'''
"""
Marks in 5 subjects are:-
1.Python:-70/100
2.java:-80/100
3.Machine Learning:-90/100
4.DBMS:-60/100
5.DSA:-75/100

"""

# %% [markdown]
# ## question on print function

# %% [markdown]
# #### 1.How do you print a string literal using print()?

# %%
print("Hello World!!")
print()
print('Hello World\'s')# escape sequence characters of single quests.
# Out:
# Hello World!!
#
# Hello World's

# %% [markdown]
# #### 2.How do you print multiple items separated by spaces?

# %%
print('Hello','Ramesh','Hello',"Shyam",sep='  ')
# Out:
# Hello  Ramesh  Hello  Shyam

# %% [markdown]
# #### 3.Can you use print without parentheses? Why or why not?

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
# print "hello"

# %%
p=input()
q=input()
def print_full_name(first, last):
    # Write your code here
    print(first)
    print(last)
print_full_name(p,q)
# Out:
# shivansh
# jadon

# %%
2

# %% [markdown]
# ## Data Structure:-
# i)list<br>
# ii)dictonary<br>
# iii)tuple<br>
# iv)set<br>

# %% [markdown]
# ### List:-[],mutable,orderded,

# %%
lst=['shivanshu','rahul','bhanu','yogesh']
print(lst)
# Out:
# ['shivanshu', 'rahul', 'bhanu', 'yogesh']

# %%
lst=[12,34,53,14]
print(lst)
print(len(lst))
sum(lst)
max(lst)
min(lst)
# Out:
# [12, 34, 53, 14]
# 4

# %% [markdown]
# ## dictonary:-{},key values pair,mutable,unordered collection

# %%
dict={"name:-":"Shivanshu","course:-":"B.Tech","RollNO:-":34}
print(dict)
print(type(dict))
print(dict["name:-"])
dict['Skills']="Python"
print(dict)
# print(name)
# Out:
# {'name:-': 'Shivanshu', 'course:-': 'B.Tech', 'RollNO:-': 34}
# <class 'dict'>
# Shivanshu
# {'name:-': 'Shivanshu', 'course:-': 'B.Tech', 'RollNO:-': 34, 'Skills': 'Python'}

# %%
print(dict.keys())
print(dict.values())
# Out:
# dict_keys(['name:-', 'course:-', 'RollNO:-'])
# dict_values(['Shivanshu', 'B.Tech', 34])

# %% [markdown]
# How to find in python library:- one cmd are use
# help('modules')

# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
# rollno=[101,102,103,104,105,106]
# names=['Raman','Aman','Amar','Manav']
# course=['BCA','MCA','BBA','M.Tech']
# df=pd.DataFrame({"RollNo":rollno,"Name":names,"Course":course})
# df

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with version '2.6.0', sqlite_version '3.42.0'
# d:\TCA_DataScience\envi\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# IPython             _warnings           html                sched
# __future__          _weakref            http                secrets
# __hello__           _weakrefset         idlelib             select
# __phello__          _winapi             imaplib             selectors
# _abc                _xxsubinterpreters  imghdr              setuptools
# _aix_support        _zoneinfo           imp                 shelve
# _ast                abc                 importlib           shlex
# _asyncio            aifc                inspect             shutil
# _bisect             antigravity         io                  signal
# ...

# %%
! pip install openpyxl
# Out:
# ...
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/c1/8b/5fe2cc11fee489817272089c4203e679c63b570a5aaeb18d852ae3cbba6a/et_xmlfile-2.0.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.9 kB 435.7 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/250.9 kB 550.5 kB/s eta 0:00:01
#    ----------------- -------------------- 112.6/250.9 kB 656.4 kB/s eta 0:00:01
#    ------------------ ------------------- 122.9/250.9 kB 654.9 kB/s eta 0:00:01
#    ----------------------------- -------- 194.6/250.9 kB 737.3 kB/s eta 0:00:01
# ...

# %%
pd.read_excel(r"D:\TCA_DataScience\Day1\myData.xlsx")
# Out:
#     Order ID Order Date  Customer ID Customer Name          Address  \
# 0       1001 2014-01-27           27    Company AA  789 27th Street
# 1       1002 2014-01-27           27    Company AA  789 27th Street
# 2       1003 2014-01-04            4     Company D   123 4th Street
# 3       1003 2014-01-04            4     Company D   123 4th Street
# 4       1003 2014-01-04            4     Company D   123 4th Street
# ..       ...        ...          ...           ...              ...
# 381     1067 2014-03-08            8     Company H   123 8th Street
# 382     1070 2014-03-03            3     Company C   123 3rd Street
# 383     1071 2014-03-03            3     Company C   123 3rd Street
# 384     1075 2014-03-10           10     Company J  123 10th Street
# 385     1077 2014-03-10           10     Company J  123 10th Street
#
#             City State  ZIP/Postal Code Country/Region       Salesperson  ...  \
# ...

# %%
pd.read_excel(r"D:\TCA_DataScience\Day1\myData.xlsx",sheet_name="Sheet2")
# Out:
#    Order ID  Product Category  Amount        State
# 0      P001  Carrots      Veg     1238      Haryana
# 1      P002  Carrots    Fruit     1776       Punjab
# 2      P003  Banana     Fruit     1138         Asam
# 3      P003  Banana     Fruit     1138         Asam
# 4      P004   Potato      Veg     1972  Uttarakhand
# 5      P005   Tomato      Veg     3456      Haryana
# 6      P006   Beans       Veg     4298       Punjab
# 7      P007  Carrots    Fruit     3666         Asam
# 8      P008  Carrots      Veg     4192  Uttarakhand
# 9      P008  Carrots      Veg     4192  Uttarakhand
# 10     P009   Tomato    Fruit     3363      Haryana
# 11     P010  Banana     Fruit     4380       Punjab
# 12     P011   Potato      Veg     3917         Asam
# 13     P012   Tomato      Veg     2263  Uttarakhand
# 14     P013   Beans       Veg     1042      Haryana
# 15     P014   Tomato    Fruit     4093       Punjab
# 16     P015  Carrots      Veg     2240         Asam
# ...

# %%
df=pd.read_excel(r"D:\TCA_DataScience\Day1\myData.xlsx",sheet_name="Sheet3")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SID       14 non-null     str
#  1   Std_Name  14 non-null     str
#  2   Eng       13 non-null     float64
#  3   Math      13 non-null     float64
#  4   Hindi     13 non-null     float64
#  5   Result    13 non-null     str
# dtypes: float64(3), str(3)
# memory usage: 948.0 bytes

# %% [markdown]
# ## set:-unordered,unindexed,mutuable

# %%
set1={1,2,3,4,5,7,9}
set1
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
set1.add(6)
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9}

# %%
set2={3,5,2,14,51}
set1.update(set2)
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9, 14, 51}

# %%
set2
# Out:
# {2, 3, 5, 14, 51}

# %% [markdown]
# ## Built_In_Function:-
# ---->1.print()<br>
# ---->2.input()<br>
# ---->3.type()<br>
# ---->4.int(),float(),str(),bool(),list(),set(),tuple(),etc<br>
# ---->5.abs()<br>
# ---->6.pow()<br>
# ---->7.min()<br>
# ---->8.max()<br>
# ---->9.round()<br>
# ---->10. divmod()<br>
# ---->11. bin(),oct(),hex()<br>
# ---->12. id()<br>
# ---->13. ord()<br>
# ---->14. help()

# %% [markdown]
# ### 1).Print()->function:-
# this function display  the output on your screen

# %%
# parameter of print() function:-  print('statement',sep=' ',end='/n')
#print(*args,sep=' ',end='/n')
# without using end()
print("Hello,")
print(" Shiva")
# Out:
# Hello,
#  Shiva

# %% [markdown]
# #### ----->print() function using sep=" "(seperator)

# %%
print("India","Pakistan","China","US")
print("India","Pakistan","China","US",sep="-")
print("India","Pakistan","China","US",sep="/")
# Out:
# India Pakistan China US
# India-Pakistan-China-US
# India/Pakistan/China/US

# %% [markdown]
# ####  -----print() function using end=" " by default ye end="\n" hota h

# %%
print("Hello", end=' ')
print("Shivanshu")
# Out:
# Hello Shivanshu

# %% [markdown]
# ### 2).input() Function:- this function take a input form user

# %%
# parameter of input() function:--> input("Prompt")
# input(prompt='')
input()# This is not best practice of input function
# Out:
# '35'

# %%
input("Enter the first Number:-")# This is best practice
# Out:
# '32'

# %% [markdown]
# ### 3).type() function:- this function is used to check the data-type.

# %%
type(2)
# Out:
# int

# %%
type(3.2)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %%
type(True)
type(False)
# Out:
# bool

# %%
type((1,3,"helo"))
# Out:
# tuple

# %%
type(["Susmita","Pragati","Shivanshu","Yogesh",345])
# Out:
# list

# %%
type({1,3,2})
# Out:
# set

# %% [markdown]
# ### 4).int(),float(),str(),bool(),list(),set(),tuple(),etc

# %%
a=6.44# float data type 
int(a) # float data type convert integer using int() function this is type conversion
# Out:
# 6

# %%
b="758.35" # this is string data type so convert 
float(b)
# ese hi sabhi use kar lena h
# Out:
# 758.35

# %% [markdown]
# ### 5). abs() function:-
# it is use this function to find the absulate mean this is very usefull for machine <br>
# that means d

# %%
abs(4)
# Out:
# 4

# %%
abs(-4)
# Out:
# 4

# %% [markdown]
# ### 6).pow() function:-
# it is a power function.

# %%
pow(2,3)
# Out:
# 8

# %% [markdown]
# ### 7).round() function:-
# it is use for round figure the decimal value<br>
# syntax:-<br>
# round(number, ndigits=None)

# %%
a=22
b=7
div=a/b
div
# Out:
# 3.142857142857143

# %%
round(div)
# Out:
# 3

# %%
round(div,3)
# Out:
# 3.143

# %% [markdown]
# ### 8). divmod() function:-
# it is used for div stand for divison that means floor divison and mod stand for modulus both operation perform at a time

# %%
divmod(35,2) # ye quotient or reminder ek saath de deta h
# Out:
# (17, 1)

# %% [markdown]
# ### 9). bin(),oct(),hex() function:-
# it is used for find the binary or ocatl or hexdecimal number find the given specific number.

# %%
bin(2)
# Out:
# '0b10'

# %%
oct(9)
# Out:
# '0o11'

# %%
hex(10)
# Out:
# '0xa'

# %% [markdown]
# ### 10). id() function:-
# it is used for find the id means a specific variable find the id

# %%
id(div)
# Out:
# 2311845641040

# %% [markdown]
# ### 11). ord() function:-
# it is used for the find the ascii value of given alphabet:-

# %%
ord('b')
# Out:
# 98

# %%
ord("B")
# Out:
# 66

# %% [markdown]
# ### 12). help() function:-
# it is used for show the documentation of the any function.

# %%
help(ord)
# Out:
# Help on built-in function ord in module builtins:
#
# ord(c, /)
#     Return the Unicode code point for a one-character string.

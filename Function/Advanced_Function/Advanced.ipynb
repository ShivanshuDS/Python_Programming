# %% [markdown]
# ### Advanced_Function:-
# --> function has two fundamental:-<br>
# 1).Abstraction:-that means this function has present but not show.<br>
# ----->Example:-bhut(ghost) h par dikhte nahi h.<br>
# 2).Decomposition:-that means <br>
# ----->Example:-multiple t.v screen pieces make a bigger t.v that is called decomposition.<br>

# %% [markdown]
# #### Components of Functions:-

# %%
'''
def:- keyword.
is_even:-function name.
i :-it is a variable/function parameters.
"""doc String""":- it is a documentation string. it is write the function how to do work and function creator name.
x=i%2==0 :- body
return x :- body
is_even():- function call
'''
def is_even(i):
 """ doc String """
 x=i%2==0
 return x
is_even(7)
# Out:
# False

# %% [markdown]
# ### Let's function create:-

# %%
def is_square(num):
    """
    1.This Function tells if a given number then 
    2.Input--any valid integer.
    3.Output--given number square
    4.Created By:-Shivanshu
    5.Last Edited:-24/07/2026
    """
    return num**2
is_square(2)
# Out:
# 4

# %% [markdown]
# ### How to check any function documentation:-

# %%
dir(is_square)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# #### 👉 The Second point of view about the function:-
# --->First Person is create a funtion and second is use the function.<br>
# --->Senior programmer create a function and junior programmer use the function.

# %%
# create the fuction
def is_even(n):
    """
    1.This function tells if a given number is even or odd.
    2.Input:-any valid integer.
    3.Output:-is even/odd.
    4.Created By:- Shivanshu.
    5.Last Edited:- 24/07/2026
    """
    if n%2==0:
        return f"{n} is Even"
    else:
        return f"{n} is odd"
def is_square(num):
    return num**2

# %%
"""
-->Use the function by juinor programmer 
ye jo function mene create kiya h wo jabhi import hoga ya use hoga another place pe jab ye function baal code 
.py file me hoga chalo me ek .py file create karta hu file name hoga (num.py)
""" 
import num
# print(dir(num)) :-> ye jinte bhi function is module ke andar h uski puri information deatah
print(num.is_even(4))
print(num.is_square(5))
# Out:
# 4 is Even
# 25

# %%
def is_even(n):
    """
    1.This function tells if a given number is even or odd.
    2.Input:-any valid integer.
    3.Output:-is even/odd.
    4.Created By:- Shivanshu.
    5.Last Edited:- 24/07/2026
    """
    if n%2==0:
        return f"{n} is Even"
    else:
        return f"{n} is odd"
print(is_even(2))
"""
Note:- ye code string value dete hi program crash kar gaya. agar humara program crash kar jaaye ye aachi practice nahi
hoti h isko short out karne ke liye ek idea h:- jab hum program me enter ho tab humara data type check ho fir hum aage
bade nahi to wo invaid data type print kar de or katam

"""
# Out:
# 2 is Even
# '\nNote:- ye code string value dete hi program crash kar gaya. agar humara program crash kar jaaye ye aachi practice nahi\nhoti h isko short out karne ke liye ek idea h:- jab hum program me enter ho tab humara data type check ho fir hum aage\nbade nahi to wo invaid data type print kar de or katam\n\n'

# %%
# modify the program without crash 
def is_even(n):
    """
    1.This function tells if a given number is even or odd.
    2.Input:-any valid integer.
    3.Output:-is even/odd.
    4.Created By:- Shivanshu.
    5.Last Edited:- 24/07/2026
    """
    if type(n)==int:
        if n%2==0:
            return f"{n} is Even"
        else:
            return f"{n} is odd"
    else:
        return f"{n}:- plz enter the valid number"
print(is_even("hello"))
# Out:
# hello:- plz enter the valid number

# %% [markdown]
# #### Parameters VS Arguments
# >Parameters:-crate a function time so pass the variable just understand the example
# >>Example:- def is_even(num):
# >>>   num is a parameter.
# ---
# >Arguments:-after creating the function and time of calling the function then pass an argument just i understand the example
# >>Example:- is_even(2)
# >>> 2 is just a argument i not pass any value then give a error
# ---
# > Python have 4 differnet Argument
# >>1.Default Argument<br>
# >>2.Positional Argument<br>
# >>3.Keyword Argument<br>
# >>4.Arbitrary Argumber

# %%
def power(a,b):
    return a**b
power(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 def power(a,b):
#       2     return a**b
# ----> 3 power(2)
#
# TypeError: power() missing 1 required positional argument: 'b'

# %% [markdown]
# >Note:-Why or when use the default Argument. show 👆👆👆👆👆 this I have pass two parameter but i use/pass atleast one argument show give me a error are u programmer just handle this so are you use a default argument

# %% [markdown]
# >#### Default Argument:-
# >>Default Argumnet is an argument so that it can handle run time error are phase an argument error so i can pass this so it is handle.

# %%
def power(a=1,b=1):
    return a**b
power(2)
# Out:
# 2

# %% [markdown]
# >#### Positional Argumnets:-
# >>it is the sequence order of passing the argument that is called positional argument<br>
# >>the means:-👇👇👇

# %%
def pow(a,b):
    return a**b
pow(2,3)

# Note:- a is assign automatic 2 and b is assign automatic 3 so this sequence called positional argument
# Out:
# 8

# %% [markdown]
# >#### Keyword Arguments:-
# >> programmer decide the passing the argument give which parameter.

# %%
def power(a,b):
    return a**b
power(b=2,a=4)

# Note:- it is not use just like a positional argument menas first argument can pass so no give for a this give the b
# --------->i can decide the this argument give this parameter that is called keyword argumnets.
# Out:
# 16

# %% [markdown]
# >#### Arbitrary Arguments:-
# >>-->Arbitrary Argumnets create a flexiable function<br>
# >>-->it just handle a many argumnets in one function.<br>
# >>Note:- (*) it is help the making many argumnet function.

# %%
def flexible(*number):
    product=1
    for i in number:
        product*=i
    print(product)
    print("it is prove that:-",number)
flexible(1) 
flexible(1,2)
flexible(1,2,3)
# show it is proof it can be make multi value pass function
# *number:- that means it is main role for making the multi value pass function. so it is create a tuple of a numbers
# Out:
# 1
# it is prove that:- (1,)
# 2
# it is prove that:- (1, 2)
# 6
# it is prove that:- (1, 2, 3)

# %% [markdown]
# ##### Global and Local Variable
# >1) Global Variable:- it is define the outside the function that is called global variable.<br>
# >2) Local Variable:- it is define the inside the function that is called local variable.

# %%
def g(y):
    print(x) # only use here global variable
    print(x+1)
g(x)# in this place use the global variable 

x=5 # it is the global variable
print(x)
# Out:
# 5
# 6
# 5

# %% [markdown]
# Note:-I can use the global variable but not modify the global variable.<br>
# -----> i can poof it 👇👇👇👇👇👇👇

# %%
def h(y):
    x=x+1
    print(x)
h(x)
x=5
print(x)
# Note:- it just throw error bcz global variable can't modify but use an alternat can be modifty lets start---
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[59], line 4
#       1 def h(y):
#       2     x=x+1
#       3     print(x)
# ----> 4 h(x)
#       5 x=5
#       6 print(x)
#
# Cell In[59], line 2, in h(y)
#       1 def h(y):
# ----> 2     x=x+1
#       3     print(x)
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
## modify/ change the global variable:-
def h(y):
    global x # jese hi mene yaha  global pass kiya bese hi progrma run
    x+=1
    print(x)
h(x)
x=5
print(x)
# Out:
# 6
# 5

# %% [markdown]
# #### Nested Function:-

# %%
def f():
    print("inside the f")
    def g():
        print("inside the g")
    g()

# Note:== pahle f function run ko call karege agar g function ko call kiya to error aaye lets do it

# %%
g()#mene g function call kiya to error show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 g()
#
# TypeError: g() missing 1 required positional argument: 'y'

# %%
f()
# Out:
# inside the f
# inside the g

# %% [markdown]
# #### Function Can be use just like as data-type / object:-

# %%
def f(num):
    return num**2
f(2)
# Out:
# 4

# %%
x=f # hame function ko ek variable me store kar diya that means aliasing kar di h jab is me ye possible h to ye integer
    # ki tarh behave karga right
x(2)# abb x bhi ek function ban gaya aliasing ke baad
# Out:
# 4

# %%
del f # f function ko delete kar diya 
f(2) # f is not define
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 del f # f function ko delete kar diya
#       2 f(2)
#
# NameError: name 'f' is not defined

# %%
x(4) # But But x function still here means aliasing function is still here means ek copy create h gayi h f function ki x me
# Out:
# 16

# %%
type(x) # it is behaves a data_type right bcz humm use karte h data type() function ko
# Out:
# function

# %%
# create a list
lst=[1,2,43,x] # yaha function store bhi ho gaya h
lst
# Out:
# [1, 2, 43, <function __main__.f(num)>]

# %%
lst[-1](3) # isne operation bhi perform kar diya h
# Out:
# 9

# %% [markdown]
# ### summery:-
# >#### 1) Renaming Function
# >#### 2) Deleting a Function
# >#### 3) Returing a Function
# >#### 4) Storing a Function
# >#### 5) Function as argument

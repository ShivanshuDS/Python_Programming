# %% [markdown]
# ## Functions:-
# step1:-Function ko define karo,#declare<br>
# step2::-Function call

# %%
def intro():
    print("Hello,I am Shivasnhu")
    print("I am Pursing B.tech(C.S.E)")
    print("I am from Up")
    print("I am currently working uptoskill as a intern")
intro()
# Out:
# Hello,I am Shivasnhu
# I am Pursing B.tech(C.S.E)
# I am from Up
# I am currently working uptoskill as a intern

# %%
# function in loop
for i in range(4):
    intro()
# Out:
# Hello,I am Shivasnhu
# I am Pursing B.tech(C.S.E)
# I am from Up
# I am currently working uptoskill as a intern
# Hello,I am Shivasnhu
# I am Pursing B.tech(C.S.E)
# I am from Up
# I am currently working uptoskill as a intern
# Hello,I am Shivasnhu
# I am Pursing B.tech(C.S.E)
# I am from Up
# I am currently working uptoskill as a intern
# Hello,I am Shivasnhu
# I am Pursing B.tech(C.S.E)
# I am from Up
# I am currently working uptoskill as a intern

# %% [markdown]
# ### Types of functions:-
# i).Built in function:- that is created by python. <br>
# _____sqrt(),pow(),read_excel()<br>
# ii).User define function:- created by user that is called <br>
# ______addition(),subtraction()<br>
# ____i)with parameter:-<br>
# __________def_add(a,b)<br>
# ____ii) withour parameter:-<br>
# __________def_add()

# %%
# without parameter user-define function
def add():
    a=int(input("Enter the value of a"))
    print("Entered Value of a:-",a)
    b=int(input("Enter the vlaue of b"))
    print("Entered Value of b:-",b)
    sum=a+b
    print("Additon of a&b:-",sum)
add()
# Out:
# Entered Value of a:- 34
# Entered Value of b:- 34
# Additon of a&b:- 68

# %%
# with paramerer

# %% [markdown]
# ### Area of rectanle :
# take

# %%
def area():
    length=int(input("Enter the value of length:-"))
    width=int(input("Entet the value of width:-"))
    area=length*width
    print(area)
area()
# Out:
# 2278

# %%
def area(l,b):
   
    area=l*b
    print(area)
area(45,3)
# Out:
# 135

# %% [markdown]
# function with return keywords:-

# %%
# ye error dega
def add(a,b):
    c=a+b
    print(c)
add(20,49)+100
# Out:
# 69
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 def add(a,b):
#       2     c=a+b
#       3     print(c)
# ----> 4 add(20,49)+100
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
def add(a,b):
    c=a+b
    return c
add(20,49)+100
# Out:
# 169

# %%
# si
def si(p,r,t):
    si=(p*r*t)/100
    return si
print("Basic fuction:-",si(2000,2,2))
print("Adding commision in si:-",si(2000,2,2)+2000)
# Out:
# Basic fuction:- 80.0
# Adding commision in si:- 2080.0

# %% [markdown]
# round figure in 2 or more digit:-

# %%
# ye new cocept h
# p
def si(p,r,t):
    si=(p*r*t)/100
    return si
print("Basic fuction:-",round(si(200000,8.55,3),2))
print("Adding commision in si:-",si(200000,8.55,3)+2000)
# Out:
# Basic fuction:- 51300.0
# Adding commision in si:- 53300.00000000001

# %%
# ye new cocept h
P=int(input("Enter the value of Principle:-"))
R=int(input("Enter the value of rate:-"))
T=int(input("Enter the value of time:-"))
def si(p,r,t):
    si=(p*r*t)/100
    return si
print("Basic fuction:-",round(si(P,R,T),2))
# print("Adding commision in si:-",si(200000,8.55,3)+2000)
# Out:
# Basic fuction:- 12000.0

# %%
def mul():
    a=6
    b=9
    return a+b
mul()
# Out:
# 15

# %%
def mul(a,b):
    
    return a+b
mul(20,40)
# Out:
# 60

# %% [markdown]
# Built in function:-

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
math.pow(2,3)# that means 2 hamara number 3 uski power h
# Out:
# 8.0

# %%
base=int(input("Enter Base:-"))
power=int(input("Enter power:-"))
result=math.pow(base,power)
print(result)
# Out:
# 8.0

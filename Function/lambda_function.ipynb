# %% [markdown]
# ## Lambda Function:- only line code function that is called lambda function

# %% [markdown]
# lambda variable_declaration:perform any task

# %% [markdown]
# area of ractangle

# %%
result=lambda l,b:l*b
result(12,23)
# Out:
# 276

# %% [markdown]
# even or odd
# if else syntax thruough lambda

# %%
test=lambda n:'Even' if(n%2==0) else "odd"
test(64)
# Out:
# 'Even'

# %% [markdown]
# greater

# %%
test=lambda a,b:'a is greater than b' if(a>b) else "b is less than a"
test(54,6)
# Out:
# 'a is greater than b'
